# %% [markdown]
# # EX: 1
# ```python
# """Hello world!
# We hope that you are learning a lot of Python.
# Have fun with our Bites of Python.
# Keep calm and code in Python!
# Become a ninja!"""
# ```
#
# Store the above msg in a variable and Write a function that takes Split the message by newline (\n) and join it together on '|' (pipe), return the obtained output string.

# %%
msg = """Hello world!
We hope that you are learning a lot of Python.
Have fun with our Bites of Python.
Keep calm and code in Python!
Become a ninja!"""
wordsList = []
def funcSplit():
   wordsList = msg.split('\n')
   print(wordsList)
   wordsList ='|'.join(wordsList)
   print(wordsList)
funcSplit()
# Out:
# ['Hello world!', 'We hope that you are learning a lot of Python.', 'Have fun with our Bites of Python.', 'Keep calm and code in Python!', 'Become a ninja!']
# Hello world!|We hope that you are learning a lot of Python.|Have fun with our Bites of Python.|Keep calm and code in Python!|Become a ninja!

# %% [markdown]
# # EX: 2
#
# - Take the block of text provided and strip off the whitespace at both ends. Split the text by newline (\n).
# - Loop through the lines, for each line:
#
# 1) strip off any leading spaces,  <br>
# 2) check if the first character is lowercase, <br>
# 3) if so, split the line into words and get the last word, <br>
# 4) strip the trailing dot (.) and exclamation mark (!) from this last word,and finally add it to the results list. <br>
# 5) Return the results list.
#
# #### Block of text to use in the program
# ``` python
# text = """
# One really nice feature of Python is polymorphism: using the same operation
# on different types of objects.
# Let's talk about an elegant feature: slicing.
# You can use this on a string as well as a list for example
# 'python'[0:2] gives 'py'.
#  The first value is inclusive and the last one is exclusive so
# here we grab indexes 0 and 1, the letter p and y.
#   When you have a 0 index you can leave it out so can write this as 'python'[:2]
# but here is the kicker: you can use this on a list too!
# ['I', 'teache', 'you', 'Python'][-2:] would gives ['you', 'Python']
# and now you know about slicing from the end as well :)
# keep enjoying our bites!
# """
# ```

# %%
from string import ascii_lowercase

text = """
One really nice feature of Python is polymorphism: using the same operation
on different types of objects.
Let's talk about an elegant feature: slicing.
You can use this on a string as well as a list for example
'python'[0:2] gives 'py'.
 The first value is inclusive and the last one is exclusive so
here we grab indexes 0 and 1, the letter p and y.
  When you have a 0 index you can leave it out so can write this as 'python'[:2]
but here is the kicker: you can use this on a list too!
['I', 'teache', 'you', 'Python'][-2:] would gives ['you', 'Python']
and now you know about slicing from the end as well :)
keep enjoying our bites!
"""
words = []
results = []

def ResultList():
    global text
    #text = text.strip().splitlines()
    #print(text)
    for line in text.strip().splitlines():
        line = line.lstrip()

        if line[0] not in ascii_lowercase:
             continue
        words = line.split()
        last_word_stripped = words[-1].rstrip('!.')
        results.append(last_word_stripped)

    return results

ResultList()
# Out:
# ['objects', 'y', 'too', ':)', 'bites']

# %% [markdown]
# # EX :3
#
# Write a function that Receives a list of numbers, and returns a filtered list of only the numbers that are both positive and even (divisible by 2), try to use a **list comprehension** .

# %%
# Python code to filter even values from a list 

# Initialisation of list 
Filteredlist = [1,2,-8,3,4,5] 

def FilterList(Filteredlist):
    Filteredlist2 = [i for i in Filteredlist if i%2 == 0 and i>-1] 
    print(Filteredlist2)
    
# Printing output 
FilterList(Filteredlist)
# Out:
# [2, 4]

# %% [markdown]
# # EX: 4
#
# - Replace all vowels in the input text string by a asteric character (*).
# - Return a tuple of (replaced_text, number_of_vowels_found)
# - So if this function is called like:
#  ``` python
# strip_vowels('hello world')
# ```
# - it would return:
# ``` python
# ('h*ll* w*rld', 3)
# ```
#
#
# #### Block of text to use in the program
# ``` python
#
# text = """
# The Zen of Python, by Tim Peters
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
# """
# ```

# %%
textMssage = """
The Zen of Python, by Tim Peters
Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way to do it.
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good idea.
Namespaces are one honking great idea -- let's do more of those!
"""
vowels = ('a', 'e', 'i', 'o', 'u')
vowelList = []
vowelcount = 0
def antivowel():   
    global textMssage
    global vowelcount
    for x in textMssage:
        if x in vowels:
            textMssage = textMssage.replace(x,"*")
            vowelcount = vowelcount + 1
            vowelList = textMssage.replace("\n","")

            
    return(vowelList,vowelcount)
antivowel()
# Out:
# ("Th* Z*n *f Pyth*n, by T*m P*t*rsB***t*f*l *s b*tt*r th*n *gly.Expl*c*t *s b*tt*r th*n *mpl*c*t.S*mpl* *s b*tt*r th*n c*mpl*x.C*mpl*x *s b*tt*r th*n c*mpl*c*t*d.Fl*t *s b*tt*r th*n n*st*d.Sp*rs* *s b*tt*r th*n d*ns*.R**d*b*l*ty c**nts.Sp*c**l c*s*s *r*n't sp*c**l *n**gh t* br**k th* r*l*s.Alth**gh pr*ct*c*l*ty b**ts p*r*ty.Err*rs sh**ld n*v*r p*ss s*l*ntly.Unl*ss *xpl*c*tly s*l*nc*d.In th* f*c* *f *mb*g**ty, r*f*s* th* t*mpt*t**n t* g**ss.Th*r* sh**ld b* *n*-- *nd pr*f*r*bly *nly *n* --*bv***s w*y t* d* *t.Alth**gh th*t w*y m*y n*t b* *bv***s *t f*rst *nl*ss y**'r* D*tch.N*w *s b*tt*r th*n n*v*r.Alth**gh n*v*r *s *ft*n b*tt*r th*n *r*ght* n*w.If th* *mpl*m*nt*t**n *s h*rd t* *xpl**n, *t's * b*d *d**.If th* *mpl*m*nt*t**n *s **sy t* *xpl**n, *t m*y b* * g**d *d**.N*m*sp*c*s *r* *n* h*nk*ng gr**t *d** -- l*t's d* m*r* *f th*s*!",
#  253)

# %% [markdown]
# # EX : 5
#
# Generate a random number between 1 and 9 (including 1 and 9). Ask the user to guess the number, then tell them whether they guessed too low, too high, or exactly right.
#
# Extras:
#
# Keep the game going until the user types “exit”
# Keep track of how many guesses the user has taken, and when the game ends, print this out.

# %%
import random
userkey = ""
tries = 0

userkey = (input("Guess the number only between 1 and 9: "))
while userkey != "exit": 
    randomNum = random.randint(1,9)
    
    try:    
     if(int(userkey) == randomNum):
        print("You Guess Exactly Right\n")
        tries += 1
        break
     elif (int(userkey) > randomNum):
        print("You Guess too High\n")
        tries += 1
        userkey = (input("Guess the number only between 1 and 9: "))
     else :
        print("You Guess too Low\n")
        tries += 1
        userkey = (input("Guess the number only between 1 and 9: "))
  
    except ValueError: 
     print(ValueError,"Please Enter correct Input")   
     userkey = (input("Guess the number only between 1 and 9: "))
    except Exception:
     print("There is an Exception")   

if (tries > 0):
    
    print("\nYou have taken ",tries,"guess/es")
# Out:
# Guess the number only between 1 and 9: 2
# You Guess too Low
#
# Guess the number only between 1 and 9: 1
# You Guess too Low
#
# Guess the number only between 1 and 9: 3
# You Guess too High
#
# Guess the number only between 1 and 9: 7
# You Guess too High
#
# Guess the number only between 1 and 9: e
# <class 'ValueError'> Please Enter correct Input
# Guess the number only between 1 and 9: 2
# You Guess too Low
#
# Guess the number only between 1 and 9: 1
# You Guess too Low
#
# Guess the number only between 1 and 9: 9
# You Guess too High
#
# Guess the number only between 1 and 9: 1
# You Guess too Low
#
# Guess the number only between 1 and 9: 3
# You Guess too Low
#
# Guess the number only between 1 and 9: 4
# You Guess too High
#
# Guess the number only between 1 and 9: 5
# You Guess too High
#
# Guess the number only between 1 and 9: 6
# You Guess too High
#
# Guess the number only between 1 and 9: 5
# You Guess too Low
#
# Guess the number only between 1 and 9: 3
# You Guess too High
#
# Guess the number only between 1 and 9: 7
# You Guess too High
#
# Guess the number only between 1 and 9: 3
# You Guess too High
#
# Guess the number only between 1 and 9: 4
# You Guess too Low
#
# Guess the number only between 1 and 9: 2
# You Guess too Low
#
# Guess the number only between 1 and 9: 7
# You Guess too Low
#
# Guess the number only between 1 and 9: 5
# You Guess too High
#
# Guess the number only between 1 and 9: 3
# You Guess too Low
#
# Guess the number only between 1 and 9: 2
# You Guess too Low
#
# Guess the number only between 1 and 9: 8
# You Guess too High
#
# Guess the number only between 1 and 9: 6
# You Guess too High
#
# Guess the number only between 1 and 9: 4
# You Guess too High
#
# Guess the number only between 1 and 9: 2
# You Guess too Low
#
# Guess the number only between 1 and 9: 1
# You Guess too Low
#
# Guess the number only between 1 and 9: 3
# You Guess too Low
#
# Guess the number only between 1 and 9: 6
# You Guess too Low
#
# Guess the number only between 1 and 9: 5
# You Guess too Low
#
# Guess the number only between 1 and 9: 7
# You Guess too Low
#
# Guess the number only between 1 and 9: 6
# You Guess Exactly Right
#
#
# You have taken  32 guess/es

# %% [markdown]
# #### 55###### EX: 6
#
# If a game of Tic Tac Toe is represented as a list of lists, like so:
# ``` python
# game = [[1, 2, 0],
# 	[2, 1, 0],
# 	[2, 1, 1]]
# ```
#
# **where a 0 means an empty square, a 1 means that player 1 put their token in that space, and a 2 means that player 2 put their token in that space** .
#
# Your task is : given a 3 by 3 list of lists that represents a Tic Tac Toe game board, tell me whether anyone has won, and tell me which player won, if any. A Tic Tac Toe win is 3 in a row - either in a row, a column, or a diagonal. Don’t worry about the case where TWO people have won - assume that in every board there will only be one winner.
#
# Here are some more examples to work with:
# ``` python
# winner_is_2 = [[2, 2, 0],
# 	[2, 1, 0],
# 	[2, 1, 1]]
#
# winner_is_1 = [[1, 2, 0],
# 	[2, 1, 0],
# 	[2, 1, 1]]
#
# winner_is_also_1 = [[0, 1, 0],
# 	[2, 1, 0],
# 	[2, 1, 1]]
#
# no_winner = [[1, 2, 0],
# 	[2, 1, 0],
# 	[2, 1, 2]]
#
# also_no_winner = [[1, 2, 0],
# 	[2, 1, 0],
# 	[2, 1, 0]]
# ```

# %%
def checkGrid(grid):
# rows
 for x in range(0,3):
  row = set([grid[x][0],grid[x][1],grid[x][2]])
  if len(row) == 1 and grid[x][0] != 0:
   return grid[x][0]

# columns
 for x in range(0,3):
  column = set([grid[0][x],grid[1][x],grid[2][x]])
  if len(column) == 1 and grid[0][x] != 0:
   return grid[0][x]

# diagonals
 diag1 = set([grid[0][0],grid[1][1],grid[2][2]])
 diag2 = set([grid[0][2],grid[1][1],grid[2][0]])
 if len(diag1) == 1 or len(diag2) == 1 and grid[1][1] != 0:
  return grid[1][1]

 

winner_is_2 = [[2, 2, 0],
[2, 1, 0],
[2, 1, 1]]
winner_is_1 = [[1, 2, 0],
[2, 1, 0],
[2, 1, 1]]

winner_is_also_1 = [[0, 1, 0],
[2, 1, 0],
[2, 1, 1]]

no_winner = [[1, 2, 0],
[2, 1, 0],
[2, 1, 2]]

also_no_winner = [[1, 2, 0],
[2, 1, 0],
[2, 1, 0]]

print("Winner is ",checkGrid(winner_is_2))
# Out:
# Winner is  2
